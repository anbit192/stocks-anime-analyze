# %%
import pandas as pd

# %%
df = pd.read_csv("../data/stocks.csv", header=[0, 1], index_col=0)
df
# Out:
# Ticker                           NFLX
# Price                            Open        High         Low       Close
# Date
# 2014-01-02 00:00:00+00:00   52.401428   52.511429   51.542858   51.831429  \
# 2014-01-03 00:00:00+00:00   52.000000   52.495712   51.842857   51.871429
# 2014-01-06 00:00:00+00:00   51.889999   52.044285   50.475716   51.367142
# 2014-01-07 00:00:00+00:00   49.684284   49.698570   48.152859   48.500000
# 2014-01-08 00:00:00+00:00   48.104286   49.425713   48.074287   48.712856
# ...                               ...         ...         ...         ...
# 2024-11-07 00:00:00+00:00  781.369995  798.219971  779.940002  796.539978
# 2024-11-08 00:00:00+00:00  797.359985  799.059998  788.650024  795.039978
# 2024-11-11 00:00:00+00:00  795.900024  806.820007  795.570007  805.440002
# 2024-11-12 00:00:00+00:00  807.500000  820.369995  803.750000  819.500000
# 2024-11-13 00:00:00+00:00  822.619995  836.989990  820.539978  830.469971
#
# ...
